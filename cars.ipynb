# %%
from csv import reader

csv_file = open('cars.csv', 'r')
content = reader(csv_file)
for row in content:
    print(row)
csv_file.close()
# Out:
# ['Car', 'Consumption', 'Cyl', 'Hp', 'Speed', 'Gears', 'Category']
# ['BMW X5', '12', '8', '220', '300', '7', 'Premium']
# ['Mazda RX4', '21', '6', '160', '110', '3.9', 'Premium']
# ['Mazda RX4 Wag', '21', '6', '160', '110', '3.9', 'Premium']
# ['Datsun 710', '22.8', '4', '108', '93', '3.85', 'Premium']
# ['Hornet 4 Drive', '21.4', '6', '258', '110', '3.08', 'Normal']
# ['Hornet Sportabout', '18.7', '8', '360', '175', '3.15"Normal"']
# ['Valiant', '18.1', '6', '225', '105', '2.76', 'Normal']
# ['Duster 360', '14.3', '8', '360', '245', '3.21', 'Normal']
# ['Merc 240D', '24.4', '4', '146.7', '62', '3.69', 'Normal']
# ['Merc 230', '22.8', '4', '140.8', '95', '3.92', 'Normal']
# ['Merc 280', '19.2', '6', '167.6', '123', '3.92', 'Normal']
# ['Merc 280C', '17.8', '6', '167.6', '123', '3.92', 'Normal']
# ['Merc 450SE', '16.4', '8', '275.8', '180', '3.07', 'Normal']
# ['Merc 450SL', '17.3', '8', '275.8', '180', '3.07', 'Normal']
# ['Merc 450SLC', '15.2', '8', '275.8', '180', '3.07', 'Normal']
# ['Cadillac Fleetwood', '10.4', '8', '472', '205', '2.93', 'Premium']
# ['Lincoln Continental', '10.4', '8', '460', '215', '3', 'Premium']
# ['Chrysler Imperial', '14.7', '8', '440', '230', '3.23', 'Premium']
# ['Fiat 128', '32.4', '4', '78.7', '66', '4.08', 'Normal']
# ['Honda Civic', '30.4', '4', '75.7', '52', '4.93', 'Normal']
# ['Toyota Corolla', '33.9', '4', '71.1', '65', '4.22', 'Normal']
# ['Toyota Corona', '21.5', '4', '120.1', '97', '3.7', 'Normal']
# ['Dodge Challenger', '15.5', '8', '318', '150', '2.76', 'Premium']
# ['AMC Javelin', '15.2', '8', '304', '150', '3.15', 'Normal']
# ['Camaro Z28', '13.3', '8', '350', '245', '3.73', 'Normal']
# ['Pontiac Firebird', '19.2', '8', '400', '175', '3.08', 'Premium']
# ['Fiat X1-9', '27.3', '4', '79', '66', '4.08', 'Normal']
# ['Porsche 914-2', '26', '4', '120.3', '91', '4.43', 'Premium']
# ['Lotus Europa', '30.4', '4', '95.1', '113', '3.77', 'Normal']
# ['Ford Pantera L', '15.8', '8', '351', '264', '4.22', 'Normal']
# ['Ferrari Dino', '19.7', '6', '145', '175', '3.62', 'Premium']
# ['Maserati Bora', '15', '8', '301', '335', '3.54', 'Premium']
# ['Volvo 142E', '21.4', '4', '121', '109', '4.11', 'Premium']

# %%
from csv import DictReader

csv_file = open('cars.csv', 'r')
content = DictReader(csv_file)
for row in content:
    print(row['Car'], row['Category'])
csv_file.close()
# Out:
# BMW X5 Premium
# Mazda RX4 Premium
# Mazda RX4 Wag Premium
# Datsun 710 Premium
# Hornet 4 Drive Normal
# Hornet Sportabout None
# Valiant Normal
# Duster 360 Normal
# Merc 240D Normal
# Merc 230 Normal
# Merc 280 Normal
# Merc 280C Normal
# Merc 450SE Normal
# Merc 450SL Normal
# Merc 450SLC Normal
# Cadillac Fleetwood Premium
# Lincoln Continental Premium
# Chrysler Imperial Premium
# Fiat 128 Normal
# Honda Civic Normal
# Toyota Corolla Normal
# Toyota Corona Normal
# Dodge Challenger Premium
# AMC Javelin Normal
# Camaro Z28 Normal
# Pontiac Firebird Premium
# Fiat X1-9 Normal
# Porsche 914-2 Premium
# Lotus Europa Normal
# Ford Pantera L Normal
# Ferrari Dino Premium
# Maserati Bora Premium
# Volvo 142E Premium

# %%
import pandas as pd 

df = pd.read_csv('cars.csv')
df
# Out:
#                     Car  Consumption  Cyl     Hp  Speed  Gears Category
# 0                BMW X5         12.0    8  220.0    300   7.00  Premium
# 1             Mazda RX4         21.0    6  160.0    110   3.90  Premium
# 2         Mazda RX4 Wag         21.0    6  160.0    110   3.90  Premium
# 3            Datsun 710         22.8    4  108.0     93   3.85  Premium
# 4        Hornet 4 Drive         21.4    6  258.0    110   3.08   Normal
# 5     Hornet Sportabout         18.7    8  360.0    175   3.15   Normal
# 6               Valiant         18.1    6  225.0    105   2.76   Normal
# 7            Duster 360         14.3    8  360.0    245   3.21   Normal
# 8             Merc 240D         24.4    4  146.7     62   3.69   Normal
# 9              Merc 230         22.8    4  140.8     95   3.92   Normal
# 10             Merc 280         19.2    6  167.6    123   3.92   Normal
# 11            Merc 280C         17.8    6  167.6    123   3.92   Normal
# 12           Merc 450SE         16.4    8  275.8    180   3.07   Normal
# 13           Merc 450SL         17.3    8  275.8    180   3.07   Normal
# 14          Merc 450SLC         15.2    8  275.8    180   3.07   Normal
# 15   Cadillac Fleetwood         10.4    8  472.0    205   2.93  Premium
# 16  Lincoln Continental         10.4    8  460.0    215   3.00  Premium
# 17    Chrysler Imperial         14.7    8  440.0    230   3.23  Premium
# 18             Fiat 128         32.4    4   78.7     66   4.08   Normal
# 19          Honda Civic         30.4    4   75.7     52   4.93   Normal
# 20       Toyota Corolla         33.9    4   71.1     65   4.22   Normal
# 21        Toyota Corona         21.5    4  120.1     97   3.70   Normal
# 22     Dodge Challenger         15.5    8  318.0    150   2.76  Premium
# 23          AMC Javelin         15.2    8  304.0    150   3.15   Normal
# 24           Camaro Z28         13.3    8  350.0    245   3.73   Normal
# 25     Pontiac Firebird         19.2    8  400.0    175   3.08  Premium
# 26            Fiat X1-9         27.3    4   79.0     66   4.08   Normal
# 27        Porsche 914-2         26.0    4  120.3     91   4.43  Premium
# 28         Lotus Europa         30.4    4   95.1    113   3.77   Normal
# 29       Ford Pantera L         15.8    8  351.0    264   4.22   Normal
# 30         Ferrari Dino         19.7    6  145.0    175   3.62  Premium
# 31        Maserati Bora         15.0    8  301.0    335   3.54  Premium
# 32           Volvo 142E         21.4    4  121.0    109   4.11  Premium

# %%
import numpy 
from scipy import stats
x = [13, 15, 6, 14, 15, 4, 20, 14, 15]
y = stats.mode(x)
numpy.mean(df['Consumption'])
# Out:
# 19.845454545454544

# %%
import matplotlib.pyplot as plt 

plt.figure(figsize=(50, 20))

n = len(df)
mcons, msp, mcyl, mhp = [],[],[],[]

m1 = numpy.mean(df['Consumption'])
m2 = numpy.mean(df['Speed'])
m3 = numpy.mean(df['Cyl'])
m4 = numpy.mean(df['Hp'])

for i in range(0, n):
    mcons.append(m1)
    msp.append(m2)
    mcyl.append(m3)
    mhp.append(m4)

plt.subplot(2, 2, 1)
plt.bar(df['Car'], df['Consumption'])
# plt.scatter(x=range(0,n), y=mcons)
plt.plot(mcons, 'g', linewidth=5)


plt.subplot(2, 2, 2)
plt.bar(df['Car'], df['Speed'])
plt.plot(msp, 'pink', linewidth=12)

plt.subplot(2, 2, 3)
plt.bar(df['Car'], df['Cyl'])
plt.plot(mcyl, 'magenta', linewidth=8)

plt.subplot(2, 2, 4)
plt.bar(df['Car'], df['Hp'])
plt.plot(mhp, '-r', linewidth=2)

plt.show()
